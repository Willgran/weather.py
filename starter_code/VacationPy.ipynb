# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     winslow  35.0242 -110.6974      9.10        15           0
# 1        1    takoradi   4.8845   -1.7554     26.20        85          91
# 2        2  bredasdorp -34.5322   20.0403     14.93        71           9
# 3        3   busselton -33.6500  115.3333     14.55        74           0
# 4        4     qaanaaq  77.4840  -69.3632    -23.91        62          34
#
#    Wind Speed     Country        Date
# 0        3.60     Winslow  1679963334
# 1        3.21   Takoradze  1679963602
# 2        1.25  Bredasdorp  1679963070
# 3        4.33   Busselton  1679963069
# 4        2.96     Qaanaaq  1679963235

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture -- no-display

# Configure the map plot
city_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5
)

# Display the map
city_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\util.py:183, in process_crs(crs)
#     182 import cartopy.crs as ccrs
# --> 183 import geoviews as gv # noqa
#     184 import pyproj
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\__init__.py:24, in <module>
#      23 from . import operation                             # noqa (API import)
# ---> 24 from . import plotting                              # noqa (API import)
#      25 from . import feature                               # noqa (API import)
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\__init__.py:19, in <module>
#      18 if 'bokeh' in backends:
# ---> 19     _load_bokeh()
#      20 if 'matplotlib' in backends:
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\__init__.py:10, in _load_bokeh()
#       9 def _load_bokeh():
# ---> 10     from . import bokeh
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\bokeh\__init__.py:30, in <module>
#      29 from ...util import poly_types, line_types
# ---> 30 from .plot import GeoPlot, GeoOverlayPlot
#      31 from . import callbacks # noqa
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\bokeh\plot.py:18, in <module>
#      15 from ..plot import ProjectionPlot
# ---> 18 class GeoPlot(ProjectionPlot, ElementPlot):
#      19     """
#      20     Plotting baseclass for geographic plots with a cartopy projection.
#      21     """
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\bokeh\plot.py:24, in GeoPlot()
#      19 """
#      20 Plotting baseclass for geographic plots with a cartopy projection.
#      21 """
#      23 default_tools = param.List(default=['save', 'pan',
# ---> 24                                     WheelZoomTool(**({} if bokeh_version < '0.12.16' else
#      25                                                      {'zoom_on_axis': False})),
#      26                                     BoxZoomTool(match_aspect=True), 'reset'],
#      27     doc="A list of plugin tools to use on the plot.")
#      29 fixed_bounds = param.Boolean(default=False, doc="""
#      30     Whether to prevent zooming beyond the projections defined bounds.""")
#
# TypeError: '<' not supported between instances of 'Version' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\Will\Downloads\Starter_Code (module_6)\Starter_Code\starter_code\VacationPy.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Configure the map plot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> city_map = city_data_df.hvplot.points(
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     "Lng",
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     "Lat",
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     geo = True,
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     tiles = "OSM",
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     frame_width = 700,
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>     frame_height = 500,
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     size = "Humidity",
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>     scale = 1,
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     color = "City",
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>     alpha = 0.5
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> # Display the map
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> city_map
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\plotting\core.py:519, in hvPlotTabular.points(self, x, y, **kwds)
#     503 def points(self, x=None, y=None, **kwds):
#     504     """
#     505     Point plot use for 2D coordinate systems
#     506
#    (...)
#     517         The HoloViews representation of the plot.
#     518     """
# --> 519     return self(x, y, kind='points', **kwds)
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\plotting\core.py:79, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      76         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      77         return pn.panel(plot, **panel_dict)
# ---> 79 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\plotting\core.py:86, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      84 y = y or params.pop('y', None)
#      85 kind = kind or params.pop('kind', None)
# ---> 86 return HoloViewsConverter(
#      87     self._data, x, y, kind=kind, **params
#      88 )
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\converter.py:343, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, figsize, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, **kwds)
#     341 self.dynamic = dynamic
#     342 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 343 self.crs = self._process_crs(data, crs) if self.geo else None
#     344 self.project = project
#     345 self.coastline = coastline
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\converter.py:572, in HoloViewsConverter._process_crs(self, data, crs)
#     570 _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     571 try:
# --> 572     return process_crs(_crs)
#     573 except ValueError:
#     574     # only raise error if crs was specified in kwargs
#     575     if crs:
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\util.py:186, in process_crs(crs)
#     184     import pyproj
#     185 except:
# --> 186     raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     188 if crs is None:
#     189     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews and cartopy.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather = city_data_df.loc[(city_data_df["Max Temp"] <= 27) & (city_data_df["Max Temp"] >= 21) &
                                 (city_data_df["Wind Speed"] <= 4.5) & (city_data_df["Cloudiness"] == 0)
                                ]

# Drop any rows with null values
ideal_weather = ideal_weather.dropna()

# Display sample data
ideal_weather
# Out:
#      City_ID                  City      Lat      Lng  Max Temp  Humidity  \
# 71        71               russell  32.3502 -85.1999     22.57       100
# 72        72            tuscaloosa  33.2098 -87.5692     23.88        41
# 148      148                ormara  25.2088  64.6357     23.20        70
# 203      203            alice town  25.7167 -79.3000     25.03        75
# 205      205            sao filipe  14.8961 -24.4956     22.92        76
# 214      214               pathein  16.7833  94.7333     25.86        72
# 283      283               neuquen -38.9516 -68.0591     24.94        29
# 307      307              jaleswar  26.6471  85.8008     21.74        29
# 318      318          saint-pierre -21.3393  55.4781     22.82        60
# 425      425                 praya  14.9215 -23.5087     23.30        68
# 433      433           grand gaube -20.0064  57.6608     24.10        80
# 479      479              barahona  18.2085 -71.1008     23.73        70
# 481      481                 houma  29.5958 -90.7195     25.00        85
# 541      541  san pedro de macoris  18.4616 -69.2972     26.07        76
#
#      Cloudiness  Wind Speed                 Country        Date
# 71            0        0.00                 Russell  1679963440
# 72            0        2.06              Tuscaloosa  1679963653
# 148           0        4.04                  Ormara  1679963788
# 203           0        4.11              Alice Town  1679963861
# 205           0        3.42              São Filipe  1679963489
# 214           0        2.41                 Pathein  1679963875
# 283           0        1.03                 Neuquén  1679963954
# 307           0        1.93               Jaleshwar  1679964002
# 318           0        3.60            Saint-Pierre  1679964018
# 425           0        2.06                   Praia  1679964167
# 433           0        1.34             Grand Gaube  1679964177
# 479           0        2.74  Santa Cruz de Barahona  1679964241
# 481           0        2.06                   Houma  1679964107
# 541           0        4.10    San Pedro de Macorís  1679964324

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather[["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
# C:\Users\Will\AppData\Local\Temp\ipykernel_25136\344292419.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                      City                 Country      Lat      Lng  Humidity  \
# 71                russell                 Russell  32.3502 -85.1999       100
# 72             tuscaloosa              Tuscaloosa  33.2098 -87.5692        41
# 148                ormara                  Ormara  25.2088  64.6357        70
# 203            alice town              Alice Town  25.7167 -79.3000        75
# 205            sao filipe              São Filipe  14.8961 -24.4956        76
# 214               pathein                 Pathein  16.7833  94.7333        72
# 283               neuquen                 Neuquén -38.9516 -68.0591        29
# 307              jaleswar               Jaleshwar  26.6471  85.8008        29
# 318          saint-pierre            Saint-Pierre -21.3393  55.4781        60
# 425                 praya                   Praia  14.9215 -23.5087        68
# 433           grand gaube             Grand Gaube -20.0064  57.6608        80
# 479              barahona  Santa Cruz de Barahona  18.2085 -71.1008        70
# 481                 houma                   Houma  29.5958 -90.7195        85
# 541  san pedro de macoris    San Pedro de Macorís  18.4616 -69.2972        76
#
#     Hotel Name
# 71
# 72
# 148
# 203
# 205
# 214
# 283
# 307
# 318
# 425
# 433
# 479
# 481
# 541

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"
params = {
    "categories":categories,
    "apiKey":geoapify_key  
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = hotel_df.loc[index, "Lng"]
    latitude = hotel_df.loc[index, "Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# russell - nearest hotel: No hotel found
# tuscaloosa - nearest hotel: No hotel found
# ormara - nearest hotel: No hotel found
# alice town - nearest hotel: No hotel found
# sao filipe - nearest hotel: No hotel found
# pathein - nearest hotel: No hotel found
# neuquen - nearest hotel: No hotel found
# jaleswar - nearest hotel: No hotel found
# saint-pierre - nearest hotel: No hotel found
# praya - nearest hotel: No hotel found
# grand gaube - nearest hotel: No hotel found
# barahona - nearest hotel: No hotel found
# houma - nearest hotel: No hotel found
# san pedro de macoris - nearest hotel: No hotel found
#                      City                 Country      Lat      Lng  Humidity  \
# 71                russell                 Russell  32.3502 -85.1999       100
# 72             tuscaloosa              Tuscaloosa  33.2098 -87.5692        41
# 148                ormara                  Ormara  25.2088  64.6357        70
# 203            alice town              Alice Town  25.7167 -79.3000        75
# 205            sao filipe              São Filipe  14.8961 -24.4956        76
# 214               pathein                 Pathein  16.7833  94.7333        72
# 283               neuquen                 Neuquén -38.9516 -68.0591        29
# 307              jaleswar               Jaleshwar  26.6471  85.8008        29
# 318          saint-pierre            Saint-Pierre -21.3393  55.4781        60
# 425                 praya                   Praia  14.9215 -23.5087        68
# 433           grand gaube             Grand Gaube -20.0064  57.6608        80
# 479              barahona  Santa Cruz de Barahona  18.2085 -71.1008        70
# 481                 houma                   Houma  29.5958 -90.7195        85
# 541  san pedro de macoris    San Pedro de Macorís  18.4616 -69.2972        76
#
#          Hotel Name
# 71   No hotel found
# 72   No hotel found
# 148  No hotel found
# 203  No hotel found
# 205  No hotel found
# 214  No hotel found
# 283  No hotel found
# 307  No hotel found
# 318  No hotel found
# 425  No hotel found
# 433  No hotel found
# 479  No hotel found
# 481  No hotel found
# 541  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    hover_cols = ["Hotel Name", "Country"]
)


# Display the map
hotel_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\util.py:183, in process_crs(crs)
#     182 import cartopy.crs as ccrs
# --> 183 import geoviews as gv # noqa
#     184 import pyproj
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\__init__.py:24, in <module>
#      23 from . import operation                             # noqa (API import)
# ---> 24 from . import plotting                              # noqa (API import)
#      25 from . import feature                               # noqa (API import)
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\__init__.py:19, in <module>
#      18 if 'bokeh' in backends:
# ---> 19     _load_bokeh()
#      20 if 'matplotlib' in backends:
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\__init__.py:10, in _load_bokeh()
#       9 def _load_bokeh():
# ---> 10     from . import bokeh
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\bokeh\__init__.py:30, in <module>
#      29 from ...util import poly_types, line_types
# ---> 30 from .plot import GeoPlot, GeoOverlayPlot
#      31 from . import callbacks # noqa
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\bokeh\plot.py:18, in <module>
#      15 from ..plot import ProjectionPlot
# ---> 18 class GeoPlot(ProjectionPlot, ElementPlot):
#      19     """
#      20     Plotting baseclass for geographic plots with a cartopy projection.
#      21     """
#
# File c:\Users\Will\anaconda3\lib\site-packages\geoviews\plotting\bokeh\plot.py:24, in GeoPlot()
#      19 """
#      20 Plotting baseclass for geographic plots with a cartopy projection.
#      21 """
#      23 default_tools = param.List(default=['save', 'pan',
# ---> 24                                     WheelZoomTool(**({} if bokeh_version < '0.12.16' else
#      25                                                      {'zoom_on_axis': False})),
#      26                                     BoxZoomTool(match_aspect=True), 'reset'],
#      27     doc="A list of plugin tools to use on the plot.")
#      29 fixed_bounds = param.Boolean(default=False, doc="""
#      30     Whether to prevent zooming beyond the projections defined bounds.""")
#
# TypeError: '<' not supported between instances of 'Version' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\Will\Downloads\Starter_Code (module_6)\Starter_Code\starter_code\VacationPy.ipynb Cell 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Configure the map plot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> hotel_map = hotel_df.hvplot.points(
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     "Lng",
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     "Lat",
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     geo = True,
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     tiles = "OSM",
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     frame_width = 700,
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>     frame_height = 500,
#       <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>     size = "Humidity",
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>     scale = 1,
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>     color = "City",
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a>     alpha = 0.5,
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a>     hover_cols = ["Hotel Name", "Country"]
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> # Display the map
#      <a href='vscode-notebook-cell:/c%3A/Users/Will/Downloads/Starter_Code%20%28module_6%29/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> hotel_map
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\plotting\core.py:519, in hvPlotTabular.points(self, x, y, **kwds)
#     503 def points(self, x=None, y=None, **kwds):
#     504     """
#     505     Point plot use for 2D coordinate systems
#     506
#    (...)
#     517         The HoloViews representation of the plot.
#     518     """
# --> 519     return self(x, y, kind='points', **kwds)
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\plotting\core.py:79, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      76         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      77         return pn.panel(plot, **panel_dict)
# ---> 79 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\plotting\core.py:86, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      84 y = y or params.pop('y', None)
#      85 kind = kind or params.pop('kind', None)
# ---> 86 return HoloViewsConverter(
#      87     self._data, x, y, kind=kind, **params
#      88 )
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\converter.py:343, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, figsize, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, **kwds)
#     341 self.dynamic = dynamic
#     342 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 343 self.crs = self._process_crs(data, crs) if self.geo else None
#     344 self.project = project
#     345 self.coastline = coastline
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\converter.py:572, in HoloViewsConverter._process_crs(self, data, crs)
#     570 _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     571 try:
# --> 572     return process_crs(_crs)
#     573 except ValueError:
#     574     # only raise error if crs was specified in kwargs
#     575     if crs:
#
# File c:\Users\Will\anaconda3\lib\site-packages\hvplot\util.py:186, in process_crs(crs)
#     184     import pyproj
#     185 except:
# --> 186     raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     188 if crs is None:
#     189     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews and cartopy.
